# %% [markdown]
# # PWave/Noise Classification Using a Random Forest Classifier
#
# ## Introduction

# %%
# %matplotlib inline

# The usual.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

# h5py is a package that let's us read/write/create .hdf5 files.
# Although pandas can read .hdf5 files, we use h5py because our data doesn't adhere to pandas' standards.
import h5py

# ML stuff.
# Data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Model
from sklearn.ensemble import RandomForestClassifier
# Validation
from sklearn import metrics
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Constants. Change as needed.
file_path = "data/scsn_p_2000_2017_6sec_0.5r_pick_train_mix.hdf5"
# Input/Output keys.
features_key = 'X'
labels_key = 'pwave'
# Data sizes
# dataset_size = 100000
dataset_size = 50000
test_size = 0.2
# RNJesus
random_state = 0

# %%
# Open the file,
file = h5py.File(file_path, 'r')

# read the file and store the relevant data into numpy.ndarrays,
dataset = file.get(features_key)[:dataset_size]
labels = file.get(labels_key)[:dataset_size]

# split the data into training and validation sets,
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_size, random_state = 0)

# then close the file.
file.close()

# %%
# Let's feature scale.
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Model Parameters. We want to see how the model performs when these vary.
# 
# n_estimators: In general, the larger the better.
# However, the larger it is, the longer it takes to compute and at some point, it stops improving the model.
# 
# max_features: The more the better. But impacts speed and can at some point be detrimental.
# For classification, a good default is sqrt(n_features).
# sklearn.models.RandomForestClassifier defaults this to 'auto'.
# 
# n_models: The number of models to evaluate.
n_estimators = 100
# Large steps just to get a quick picture of how the models performance is dependent on n_estimators.
n_estimators_step = 100
# max_features = sqrt(len(dataset[0]))
n_models = 20

# %%
# Time to train the models and generate the metrics needed to evaluate their performances.
total_time_passed = datetime.datetime.now()
classifiers = []
for x in range(n_models):
    # Let's see how long it takes to train a model.
    then = datetime.datetime.now()
    
    n_e = n_estimators + n_estimators_step * x
    # Define the model.
    classifier = RandomForestClassifier(
        n_estimators=n_e,
        random_state=random_state
    )
    # Train the model.
    classifier.fit(X_train, y_train)
    # Have it predict some stuff from the test data.
    y_pred = classifier.predict(X_test)
    # Generate the models metrics.
    classifier_metadata = {
        "n_estimators": n_e,
        "mae": metrics.mean_absolute_error(y_test, y_pred),
        "mse": metrics.mean_squared_error(y_test, y_pred),
        "rmse": np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    }
    # Add the model and its metrics to the list of classifiers.
    classifiers.append({
        "classifier": classifier,
        "classifier_metadata": classifier_metadata
    })
    
    # Record the passage of time.
    now = datetime.datetime.now()
    time_passed = now - then
    total_time_passed += time_passed
    print(f"Model no. {x} (no. estimators: {n_e}) completed in {time_passed}")
else:
    print(f"Total time passed: {total_time_passed}")
# Out:
# Model no. 0 (no. estimators: 100) completed in 0:03:09.062983
# Model no. 1 (no. estimators: 200) completed in 0:06:10.038615
# Model no. 2 (no. estimators: 300) completed in 0:09:15.921686
# Model no. 3 (no. estimators: 400) completed in 0:12:27.039375
# Model no. 4 (no. estimators: 500) completed in 0:15:24.850346
# Model no. 5 (no. estimators: 600) completed in 0:18:31.457229
# Model no. 6 (no. estimators: 700) completed in 0:21:32.424231
# Model no. 7 (no. estimators: 800) completed in 0:24:46.510898
# Model no. 8 (no. estimators: 900) completed in 0:27:53.108395
# Model no. 9 (no. estimators: 1000) completed in 0:31:04.215807
# Model no. 10 (no. estimators: 1100) completed in 0:35:08.398076
# Model no. 11 (no. estimators: 1200) completed in 0:38:49.425178
# Model no. 12 (no. estimators: 1300) completed in 0:49:26.943981
# Model no. 13 (no. estimators: 1400) completed in 0:55:23.553023
# Model no. 14 (no. estimators: 1500) completed in 1:03:55.159206
# Model no. 15 (no. estimators: 1600) completed in 1:13:57.987388
# Model no. 16 (no. estimators: 1700) completed in 1:08:23.206029
# Model no. 17 (no. estimators: 1800) completed in 1:10:12.163416
# Model no. 18 (no. estimators: 1900) completed in 1:03:45.079503
# Model no. 19 (no. estimators: 2000) completed in 1:08:36.249603
# Total time passed: 2019-01-21 05:11:13.902837

# %%
# Finally, let's look at the metrics.

# Define the independent variable.
x = np.arange(n_estimators, n_estimators + n_models * n_estimators_step, n_estimators_step)

# Mean Absolute Error
plt.title("MAE for Various PWave/Noise RFCs")
plt.xlabel('Number of Estimators')
plt.ylabel("Mean Absolute Error")
y = []
for classifier in classifiers:
    y.append(classifier['classifier_metadata']['mae'])
plt.plot(x, y, 'r.-')
plt.show()

# Mean Squared Error
plt.title("MSE for Various PWave/Noise RFCs")
plt.xlabel("Number of Estimators")
plt.ylabel("Mean Squared Error")
y = []
for classifier in classifiers:
    y.append(classifier['classifier_metadata']['mse'])
plt.plot(x, y, 'g.-')
plt.show()

# Root Mean Squared Error
plt.title("RMSE for Various PWave/Noise RFCs")
plt.xlabel("Number of Estimators")
plt.ylabel("Root Mean Squared Error")
y = []
for classifier in classifiers:
    y.append(classifier['classifier_metadata']['rmse'])
plt.plot(x, y, 'b.-')

plt.show()

# %% [markdown]
# ## Appendix

# %% [markdown]
# ## Resources
# * [1.11 Ensemble Methods (Scikit-Learn)](https://scikit-learn.org/stable/modules/ensemble.html)
# * [Random Forest Algorithm With Python and Scikit-Learn (Stack Abuse)](https://stackabuse.com/random-forest-algorithm-with-python-and-scikit-learn/)
